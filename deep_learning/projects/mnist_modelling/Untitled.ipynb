# %% [markdown]
# # Handwritten digits classification using convolution neural network

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Conv2D, MaxPooling2D, InputLayer, Flatten, Dense, BatchNormalization, Dropout

# %%
# Load dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
# Reshape image in 4D
X_train = X_train.reshape(-1, 28, 28 ,1)
X_test = X_test.reshape(-1, 28, 28, 1)

# %%
# Normalize X pixel values to be between 0 and 1
X_tain = X_train / 255
X_test = X_test / 255

# %%
# One hot encoding
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
# Create convolution layer
model = Sequential([
    InputLayer(shape=(28, 28, 1)),
    
    Conv2D(filters=32, kernel_size=(3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    BatchNormalization(),

    Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.2),
    
    Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    
    Flatten(),
    
    Dense(units=128, activation='relu'),
    Dense(units=10, activation='softmax')
])

# %%
# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
callbacks = [
    EarlyStopping(monitor='loss', patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor='loss', factor=0.3, patience=3)
]

# %%
# Train model
model_history = model.fit(X_train, y_train, epochs=10, batch_size=64, callbacks=callbacks)
# Out:
# Epoch 1/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 33s 29ms/step - accuracy: 0.9368 - loss: 0.2026 - learning_rate: 0.0010
# Epoch 2/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 29s 31ms/step - accuracy: 0.9750 - loss: 0.0801 - learning_rate: 0.0010
# Epoch 3/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 29s 31ms/step - accuracy: 0.9817 - loss: 0.0580 - learning_rate: 0.0010
# Epoch 4/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 32s 34ms/step - accuracy: 0.9845 - loss: 0.0487 - learning_rate: 0.0010
# Epoch 5/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 30s 32ms/step - accuracy: 0.9866 - loss: 0.0427 - learning_rate: 0.0010
# Epoch 6/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 32s 34ms/step - accuracy: 0.9882 - loss: 0.0360 - learning_rate: 0.0010
# Epoch 7/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 31s 33ms/step - accuracy: 0.9891 - loss: 0.0341 - learning_rate: 0.0010
# Epoch 8/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 34s 36ms/step - accuracy: 0.9900 - loss: 0.0305 - learning_rate: 0.0010
# Epoch 9/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 34s 36ms/step - accuracy: 0.9913 - loss: 0.0271 - learning_rate: 0.0010
# Epoch 10/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 32s 34ms/step - accuracy: 0.9922 - loss: 0.0235 - learning_rate: 0.0010

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.1135 - loss: 3.8735
# [3.873532772064209, 0.11349999904632568]

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.1135 - loss: 3.8735
# [3.873532772064209, 0.11349999904632568]
