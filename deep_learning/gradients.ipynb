# %% [markdown]
# # Gradients

# %% [raw]
# Gradients:
#     Gradients will update weights and bias of nueral network to reduce loss during training.
#     They determine how fast, how smoothly and how intellegently model learns.
#
# Gradient Descent (GD):
#     w = w - lr * dL/dw     # lr = Learning rate
#     Updates all weights at once using the entire dataset.
#     It is simple and accurate.
#     Very slow and not used in practical deep larning, because for entire dataset it will calculate at once so need high GPU and CPU.
#
# Stochastic Gradient Descent (SGD):
#     w = w - lr * gradient
#     weitht updates will happen for one sample at a time.
#     Faster than Gradient Descent but slow due to one sample at a time, what if one million records
#
# Mini-Batch SGD:
#     Uses small batches of data (32, 64, etc.)
#     Best balance of speed + stability.
#
# Momentum:
#     v=βv+αg, w=w−v
#     Adds "memory" to the updates → moves faster in the right direction.
#
# AdaGrad:
#     Using high learning rate in begining and slowly decreased learning rate towards global minima.
#     w = w − (lr/sqrt(G + e)) * gradient
#     Larger updates for infrequent features, Smaller updates for frequent features. Means begining leraning rate is high, after learning starts it will     reduce towards global minima
#     Learning may become very small that it wll make gradient values will be almost zero.
#
# RMSProp:
#     G=βG+(1−β)g2
#     Fixes AdaGrad’s problem of shrinking learning rates too much.
#
# Adam:
#     mt = β1 * mt−1 + (1−β1) * g
#     vt = β2 * vt−1 + (1−β2) * g2
#     w = w − α * (mt/((sqrt(vt) + e))
#     Adam = Momentum + RMSProp. Best default optimizer for deep learning.
