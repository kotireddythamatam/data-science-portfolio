# %%
import pandas as pd
import numpy as np

# %%
n = np.random.randint(100)
n
# Out:
# 53

# %%
n = np.random.rand()
n
# Out:
# 0.24391833141087127

# %%
array = np.random.randint(100, size=(3))
array
# Out:
# array([71, 48, 96], dtype=int32)

# %%
array = np.random.randint(100, size=(3,3))
array
# Out:
# array([[82, 80, 42],
#        [12, 48, 21],
#        [ 1, 17,  2]], dtype=int32)

# %%
array = np.random.rand(3)
array
# Out:
# array([0.11755124, 0.25417946, 0.21471843])

# %%
array = np.random.rand(3,2)
array
# Out:
# array([[0.97079458, 0.89623554],
#        [0.52189222, 0.21584932],
#        [0.88958949, 0.64261533]])

# %%
c = np.random.choice([1,2,3,4])
c
# Out:
# np.int64(3)

# %%
c = np.random.choice([1,2,3,4], size=(2,2))
c
# Out:
# array([[2, 1],
#        [4, 3]])

# %%
array = np.random.choice([1,3,5,7], p=[0.1,0.2,0.3,0.4], size=(100))
array
# Out:
# array([7, 7, 3, 7, 3, 7, 5, 5, 7, 7, 1, 5, 3, 7, 3, 7, 1, 5, 3, 7, 7, 7,
#        5, 7, 7, 3, 5, 3, 7, 1, 5, 7, 5, 5, 7, 5, 1, 5, 5, 5, 7, 5, 3, 7,
#        5, 1, 5, 5, 7, 5, 7, 7, 7, 7, 1, 5, 7, 3, 7, 5, 7, 1, 7, 7, 1, 7,
#        7, 5, 7, 1, 5, 7, 1, 5, 7, 7, 7, 5, 3, 5, 1, 7, 5, 5, 5, 5, 5, 7,
#        5, 7, 3, 3, 1, 5, 5, 3, 1, 5, 5, 7])

# %%
arary = np.random.choice([1,3,5,7], p=[0.0, 0.1, 0.3,0.6], size=(2,3))
arary
# Out:
# array([[7, 7, 5],
#        [7, 7, 5]])

# %%
array = np.random.randint(100, size=(5))
array
# Out:
# array([40, 30, 99, 52, 99], dtype=int32)

# %%
np.random.shuffle(array)
array
# Out:
# array([99, 52, 99, 40, 30], dtype=int32)

# %%
array = np.random.randint(100, size=(5))
array
# Out:
# array([57, 66, 87, 70, 57], dtype=int32)

# %%
new_array = np.random.permutation(array)
array, new_array
# Out:
# (array([57, 66, 87, 70, 57], dtype=int32),
#  array([57, 66, 57, 70, 87], dtype=int32))

# %%
normal_dist = np.random.normal(size=(3,2))
normal_dist
# Out:
# array([[ 2.04652579,  0.64412977],
#        [-1.0980887 ,  0.6176218 ],
#        [-0.22378019, -0.15025678]])

# %%
normal_dist = np.random.normal(loc=1, scale=2, size=(3,3))
normal_dist
# Out:
# array([[ 0.47736394, -1.97590841,  1.27965376],
#        [ 2.58155672,  0.12540369,  1.61989467],
#        [ 1.41971624,  1.30859538,  4.8838895 ]])

# %%
binomial_dist = np.random.binomial(n=10, p=0.5, size=10)
binomial_dist
# Out:
# array([8, 2, 6, 4, 5, 3, 7, 5, 6, 7], dtype=int32)

# %%
poission_dist = np.random.poisson(lam=2, size=10)
poission_dist
# Out:
# array([1, 2, 2, 3, 3, 3, 2, 1, 0, 2], dtype=int32)

# %%
uniform_dist = np.random.uniform(size=(20))
uniform_dist
# Out:
# array([0.78049977, 0.81454322, 0.58081615, 0.71773868, 0.5630928 ,
#        0.36619493, 0.77253365, 0.29324981, 0.932805  , 0.47208943,
#        0.28644107, 0.23388149, 0.71057238, 0.87220829, 0.81707491,
#        0.56912089, 0.37043122, 0.83659672, 0.65584493, 0.4342256 ])

# %%
logistic_dist = np.random.logistic(loc=1, scale=2, size=(2, 3))
logistic_dist
# Out:
# array([[ 5.31378566,  7.85983411, -2.99167108],
#        [-3.69626568,  5.7125554 , -0.27381197]])

# %%
multi_dist = np.random.multinomial(n=6, pvals=[1/6, 1/6, 1/6, 1/6, 1/6, 1/6])
multi_dist
# Out:
# array([1, 1, 0, 2, 1, 1], dtype=int32)

# %%
exp_dist = np.random.exponential(scale=2, size=(2, 3))
exp_dist
# Out:
# array([[ 0.90704632,  0.3457244 ,  0.27761773],
#        [ 0.77126276,  0.55468239, 10.08104923]])

# %%
chi_dist = np.random.chisquare(df=2, size=(2, 3))
chi_dist
# Out:
# array([[0.5829882 , 1.47493476, 1.03060363],
#        [0.96899654, 5.02029987, 1.04012203]])

# %%
ray_dist = np.random.rayleigh(scale=2, size=(2, 3))
ray_dist
# Out:
# array([[5.16249607, 6.26867032, 1.50990092],
#        [0.92924459, 0.34763853, 2.66180955]])

# %%
par_dist = np.random.pareto(a=2, size=(2, 3))
par_dist
# Out:
# array([[0.00901235, 1.05615419, 0.10795106],
#        [1.13331453, 4.95765668, 1.69944189]])

# %%
zip_dist = np.random.zipf(a=2, size=(2, 3))
zip_dist
# Out:
# array([[ 1,  1, 50],
#        [ 2,  1,  4]], dtype=int32)

# %%
np.array([1,1.2, True, 'ada'])
# Out:
# array(['1', '1.2', 'True', 'ada'], dtype='<U32')
