# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import random

# %%
x = [0,1,2,3,4]
y = [0,3,5,8, 10]
plt.plot(x, y)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x,y,marker='o',label='x y label')
ax.set_title('x y title')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
plt.show()

# %%
y = ['a', 'b', 'c', 'd']
x = [10, 20, 30, 40]
plt.pie(x, labels=y, autopct='%1.1f%%')
plt.show()

# %%
x = ['A', 'b','c','d']
y=[3,7,2,5]
plt.bar(x, y)
plt.show()

# %%
x = [0, 1,2,3,4]
y = [1,2,3,4,5]
plt.scatter(x, y)
plt.show()

# %%
data = np.random.randn(1000)
plt.hist(data, bins=30)
plt.show()

# %%
df = pd.read_csv('../../datasets/nba.csv')
df.dropna(inplace=True)
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
#
#       College     Salary
# 0       Texas  7730337.0
# 1   Marquette  6796117.0
# 6         LSU  1170960.0
# 7     Gonzaga  2165160.0
# 8  Louisville  1824360.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 363 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      363 non-null    object
#  1   Team      363 non-null    object
#  2   Number    363 non-null    float64
#  3   Position  363 non-null    object
#  4   Age       363 non-null    float64
#  5   Height    363 non-null    object
#  6   Weight    363 non-null    float64
#  7   College   363 non-null    object
#  8   Salary    363 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 28.4+ KB

# %%
df.nunique()
# Out:
# Name        363
# Team         30
# Number       51
# Position      5
# Age          22
# Height       17
# Weight       76
# College     114
# Salary      255
# dtype: int64

# %%
plt.plot(df['Age'], df['Position'])
plt.show()

# %%
# Identify which age groups have more salary
plt.bar(df['Age'], df['Salary'])
plt.show()

# %%
plt.pie(df['Weight'], labels=df['Position'], autopct='%1.1f%%')
plt.show()

# %%
plt.hist(df['Weight'], bins=30)
plt.show()

# %%
plt.scatter(df['Age'], df['Weight'])
plt.show()

# %%
fig = plt.figure()
ax = plt.axes([0.1,0.1,0.8,0.8])

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.legend(labels = ('l1', 'l2'), loc='upper left')

# %%
x = [1, 2, 3]
y = [0, 1, 0]
z = [1, 0, 1]
fig, ax = plt.subplots(3)
ax[0].plot(x,y)
ax[1].plot(x, z)

# %%
fig, ax = plt.subplots(2,2)
ax[0, 0].plot([1,2,3], [4,5,6])
ax[0, 0].set_title("Linear")
ax[0, 1].scatter([1,2,3], [4,5,6])
ax[0, 1].set_title('scatter')
ax[1, 0].bar([1,2,3], [4,5,6])
ax[1, 0].set_title("bar")
ax[1, 1].hist([1,2,3,4,5,6,7,8,9])
ax[1, 1].set_title("hist")
fig.tight_layout()
plt.show()

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]
plt.plot(x,y)
plt.legend(['x y element'])
plt.show()

# %%
y1 = [2, 3, 4.5]
y2 = [1, 1.5, 5]
plt.plot(y1)
plt.plot(y2)
plt.legend(['y1', 'y2'], loc='best')
plt.show()

# %%
# Y-axis values
y1 = [1, 2, 3, 4, 5]

# Y-axis values
y2 = [1, 4, 9, 16, 25]

plt.plot(y1, y2, label='y1')
plt.plot(y2, y1, label='y2')
plt.legend(loc='upper left')
plt.show()

# %%
# Y-axis values
y1 = [1, 2, 3, 4, 5]

# Y-axis values
y2 = [1, 4, 9, 16, 25]

plt.plot(y1, label='y1')
plt.plot(y2, label='y2')
plt.legend(loc='lower right')
plt.show()

# %%
x = np.linspace(1, 50, 50)
np.random.seed(1)
y = np.random.randint(0, 20, 50)
plt.plot(x, y)
plt.legend(['legend'], loc='lower right')
plt.show()

# %%
plt.plot(x, label='x values')
plt.plot(y, label='y values')
plt.legend(loc='center right')
plt.show()

# %%
plt.figure(figsize = (8, 4))
x = ['Arjun', 'Bharath', 'Raju', 'Seeta', 'Ram']
y = [5, 7, 8, 4, 6]
plt.bar(x, y, color='g')
plt.xlabel('Students', fontsize=10)
plt.ylabel('Marks', fontsize=10)
plt.legend(["marks"], fontsize=10)
plt.show()

# %%
plt.figure(figsize = (8 , 5))

plt.plot([1, 2, 4, 8, 30, 1])
plt.plot([1, 6, 13, 20, 38, 1])
plt.plot([1, 4, 8, 14, 20, 1])
plt.plot([1, 3, 4, 5, 10, 1])

plt.legend(['a', 'b', 'c', 'd'], prop={'size': 10}, loc='upper left', shadow=True, facecolor='yellow')
plt.show()

# %%
plt.figure(figsize=(3,3))
plt.plot([0, 1], [0, 2.0], label = 'Label-1')
plt.plot([1, 2], [0, 2.1], label = 'Label-2')
plt.plot([2, 3], [0, 2.2], label = 'Label-3')
plt.legend(labelspacing=2)
plt.title('line grap')
plt.show()

# %%
fig = plt.figure()

# 4 subplots in 2 rows and 2 columns in a figure
axes = fig.subplots(nrows=2, ncols=2)

axes[0, 0].bar(['Telugu', 'Hindi', 'English', 
                'Maths', 'Science', 'Social'],
               [50, 27, 42, 34, 45, 48], 
               color='g', label="Students passed in 2017")

axes[0, 0].set_yticks(np.arange(0, 51, 5))

axes[0, 1].bar(['Telugu', 'Hindi', 'English', 
                'Maths', 'Science', 'Social'],
               [50, 27, 42, 34, 45, 48], 
               color='y', label="Students passed in 2018")

axes[0, 1].set_yticks(np.arange(0, 51, 5))

axes[1, 0].bar(['Telugu', 'Hindi', 'English', 
                'Maths', 'Science', 'Social'],
               [40, 27, 22, 44, 35, 38],
               color='r', label="Students passed in 2019")

axes[1, 0].set_yticks(np.arange(0, 51, 5))
axes[1, 0].set_xlabel('Subjects', fontsize=25)

# rotating third sub-plot x-axis labels
for tick in axes[1, 0].get_xticklabels():
    tick.set_rotation(45)

axes[1, 0].set_ylabel(" Number of Students passed in 2017-2020", fontsize=20)


axes[1, 1].bar(['Telugu', 'Hindi', 'English',
                'Maths', 'Science', 'Social'],
               [40, 27, 32, 44, 45, 48], 
               color='b', label="Students passed in 2020")

axes[1, 1].set_xlabel('Subjects', fontsize=20)
axes[1, 1].set_yticks(np.arange(0, 51, 5))


lines = []
labels = []

for ax in fig.axes:
    Line, Label = ax.get_legend_handles_labels()
    # print(Label)
    lines.extend(Line)
    labels.extend(Label)

# rotating x-axis labels of last sub-plot
plt.xticks(rotation=45)

fig.legend(lines, labels, loc='upper right')

plt.show()

# %%
plt.plot([1,2,3,4,5])
plt.title('title')
plt.legend(['legend'])
plt.show()

# %%
x = [1,2,3,4]
y = [2,4,8,16]
plt.plot(x, y)
plt.show()

# %%
x = [1,2,3,4]
y = [2,4,8,16]
plt.plot(x, y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('xy-axis')
plt.show()

# %%
x = [1,2,3,4]
y = [2,4,8,16]
plt.plot(x, y)
plt.legend(['ab'], loc='upper left')
plt.grid(True)
plt.show()

# %%
x = [1,2,3,4]
y = [2,4,8,16]
plt.figure(figsize=(4,4))
plt.plot(x, y, marker='o', linestyle='-')

for i, (xi, yi) in enumerate(zip(x,y)):
    plt.annotate(f"({xi}, {yi})", (xi, yi), textcoords='offset points', xytext=(0, 10), ha='center')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Line Chart with Annotations')
plt.grid(True)
plt.show()

# %%
x = [1,2,3,4]
y = [2,4,8,16]

plt.figure(figsize=(5,5))
plt.plot(x, y, '-.')
plt.show()

# %%
x = [1,2,3,4]
y = [2,4,8,16]

plt.plot(x,y)
plt.plot(y,x)
plt.show()

# %%
x = [1,2,3,4]
y = [2,4,6,8]

x1 = [2, 4, 6, 8]
y1 = [3, 5, 7, 9]

plt.figure(figsize=(5,5))
plt.plot(x, y)
plt.plot(x1, y1)
plt.fill_between(x, y, y1)
plt.show()

# %%
# Line chart used to show relation between two data points.
x = np.array([1,2,3,4])
y = x * 2
plt.plot(x, y)
plt.show()

# %%
x = np.array([1,2,3,4])
y = x * 2
plt.plot(x, y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Line chart')
plt.show()

# %%
x = np.array([1,2,3,4])
y = x * 2
plt.plot(x, y)
for i, (xi, yi) in enumerate(zip(x,y)):
    plt.annotate(f'({xi}, {yi})', (xi, yi), textcoords='offset points', xytext=(0, 10), ha='center')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Line chart')
plt.grid(True)
plt.show()

# %%
x = np.array([1,2,3,4])
y = x * 2

plt.figure(figsize=(5,5))
plt.plot(x, y)
for i, (xi, yi) in enumerate(zip(x,y)):
    plt.annotate(f'({xi}, {yi})', (xi, yi), textcoords='offset points', xytext=(0, 10), ha='center')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Line chart')
plt.grid(True)
plt.show()

plt.figure(figsize=(4,5))
plt.plot(x, y, '-.')
for i, (xi, yi) in enumerate(zip(x,y)):
    plt.annotate(f'({xi}, {yi})', (xi, yi))
plt.xlabel('x1-axis')
plt.ylabel('y1-axis')
plt.title('Line chart new')
plt.show()

# %%
x = np.array([1,2,3,4])
y = x * 2

x1 = [2, 4, 6, 8]
y1 = [3, 5, 7, 9]

plt.plot(x, y)

plt.plot(x1, y1)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Line charts')
plt.show()

# %%
x = np.array([1,2,3,4])
y = x * 2

x1 = [2, 4, 6, 8]
y1 = [3, 5, 7, 9]

plt.plot(x, y)

plt.plot(x1, y1)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Line charts')
plt.fill_between(x, y, y1, color='green', alpha=0.5)
plt.show()

# %%
students = ["Jane","Joe","Beck","Tom",
            "Sam","Eva","Samuel","Jack",
            "Dana","Ester","Carla","Steve",
            "Fallon","Liam","Culhane","Candance",
            "Ana","Mari","Steffi","Adam"]
marks = []
for i in range(0, len(students)):
    marks.append(random.randint(1, 100))

plt.figure(figsize=(12,6))
plt.plot(students, marks, color='green', linestyle=':', marker='*', markerfacecolor='red', markersize=10)
plt.xlabel('students')
plt.ylabel('marks')
plt.title('Student Marks')
plt.show()

# %%
students = ["Jane","Joe","Beck","Tom",
            "Sam","Eva","Samuel","Jack",
            "Dana","Ester","Carla","Steve",
            "Fallon","Liam","Culhane","Candance",
            "Ana","Mari","Steffi","Adam"]
marks = []
for i in range(0, len(students)):
    marks.append(random.randint(1, 100))

plt.figure(figsize=(12,6))
plt.plot(students, marks, label="xy", color='green', linestyle='-.', marker='v', markerfacecolor='red', markersize=10)
plt.xlabel('students')
plt.ylabel('marks')
plt.title('Student Marks')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# %%
x = [10,20,30,40,50]
y = [30,30,30,30,30]

plt.plot(x, y, label='xy plot', linestyle='--')
plt.plot(y, x, label='yx plot', linestyle='-.')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('xy data')
plt.legend()
plt.show()

# %%
students = ["Jane","Joe","Beck","Tom",
            "Sam","Eva","Samuel","Jack",
            "Dana","Ester","Carla","Steve",
            "Fallon","Liam","Culhane","Candance",
            "Ana","Mari","Steffi","Adam"]
marks = []
for i in range(0, len(students)):
    marks.append(random.randint(1, 100))

plt.figure(figsize=(12,6))
plt.plot(students, marks, label="xy", color='green', alpha=0.5, linewidth=2, linestyle='-.', marker='v', markerfacecolor='red', markersize=10)
plt.xlabel('students')
plt.ylabel('marks')
plt.title('Student Marks')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# %%
students = ["Jane","Joe","Beck","Tom",
            "Sam","Eva","Samuel","Jack",
            "Dana","Ester","Carla","Steve",
            "Fallon","Liam","Culhane","Candance",
            "Ana","Mari","Steffi","Adam"]
marks = []
for i in range(0, len(students)):
    marks.append(random.randint(1, 100))

plt.figure(figsize=(12,6))
plt.plot(students, marks, label="xy", color=(0,0,1,0.5), alpha=0.5, linewidth=2, linestyle='-.', marker='v', markerfacecolor='red', markersize=10)
plt.xlabel('students')
plt.ylabel('marks')
plt.title('Student Marks')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# %%
a = ['red', 'green', 'blue', 'purple'] # colors
b = [0.1, 0.3, 0.5, 0.8] # alphas
x = np.linspace(0, 10, 100)

for i in range(4):
    plt.plot(x, np.sin(x+i), color=a[i], alpha=b[i], label=f'{a[i]}')
plt.legend()
plt.show()

# %%
places = ["A", "B", "C", "D", "E", "F", "G", "H", "I", "J"]
literacy_rate = [100, 98, 90, 85, 75, 50, 30, 45, 65, 70]
female_literacy = [95, 100, 50, 60, 85, 80, 75, 99, 70, 30]

plt.plot(places, literacy_rate, color='green', linewidth=1.5, label='PL', marker='v', markerfacecolor='red', markersize=10)
plt.plot(places, female_literacy, color='red', linewidth=1.5, label='PF', marker='o', markerfacecolor='green', markersize=5)
plt.xlabel('x-axis', labelpad=10)
plt.ylabel('y-axis', labelpad=2)
plt.legend(loc='lower left')
plt.show()

# %%
x = [1, 2, 1, 0]
y = [2, 1, 0, 1]

plt.plot(x, y)
plt.fill(x,y)
plt.show()

# %%
x = [1, 2, 1, 0]

plt.plot(x)
plt.show()

# %%
df = pd.read_csv('../../datasets/nba.csv')
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0      NaN  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF   NaN   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      456 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  456 non-null    object
#  4   Age       456 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  456.000000  457.000000  4.460000e+02
# mean    17.678337   26.934211  221.522976  4.842684e+06
# std     15.966090    4.407792   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 363 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      363 non-null    object
#  1   Team      363 non-null    object
#  2   Number    363 non-null    float64
#  3   Position  363 non-null    object
#  4   Age       363 non-null    float64
#  5   Height    363 non-null    object
#  6   Weight    363 non-null    float64
#  7   College   363 non-null    object
#  8   Salary    363 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 28.4+ KB

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
#
#       College     Salary
# 0       Texas  7730337.0
# 1   Marquette  6796117.0
# 6         LSU  1170960.0
# 7     Gonzaga  2165160.0
# 8  Louisville  1824360.0

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Age'][:5], df['College'][:5], label='College student ages', color='green', linestyle='--', linewidth=2, marker='D', markerfacecolor='red', markersize=5, alpha=0.5)
for i, (xi, yi) in enumerate(zip(df['Age'][:5], df['College'][:5])):
    plt.annotate(f'({xi}, {yi})', (xi, yi), textcoords='offset points', xytext=(0, 10), ha='center')
plt.xlabel('Age', labelpad=10)
plt.ylabel('College')
plt.title('College Student Info')
plt.legend(loc='lower left')
plt.grid(True, linestyle='--', linewidth=0.5)
plt.show()

# %%
fruits = ['Apples', 'Bananas', 'Cherries', 'Dates']
sales = [400, 350, 300, 450]

plt.bar(fruits, sales, color='green')
plt.show()

# %%
fruits = ['Apples', 'Bananas', 'Cherries', 'Dates']
sales = [400, 350, 300, 450]

plt.bar(fruits, sales, color='green', width=0.1)
plt.show()

# %%
barWidth = 0.25
plt.figure(figsize=(12, 8))
IT = [12, 30, 1, 8, 22] 
ECE = [28, 6, 16, 5, 10] 
CSE = [29, 3, 24, 25, 17] 

bar1 = np.arange(len(IT))
bar2 = [x + barWidth for x in bar1]
bar3 = [x + barWidth for x in bar2]

plt.bar(bar1, IT, width=0.2, label='IT', edgecolor='grey')
plt.bar(bar2, ECE, width=0.2, label='ECE', edgecolor='grey')
plt.bar(bar3, CSE, width=0.2, label='CSE', edgecolor='grey')

plt.xlabel('Branch', fontweight='bold', fontsize=15)
plt.ylabel('Students Passed', fontweight='bold', fontsize=15)
plt.xticks([r + barWidth for r in range(len(IT))], 
        ['2015', '2016', '2017', '2018', '2019'])

plt.legend()
plt.show()

# %%
barWidth = 0.25
ind = np.arange(5)
plt.figure(figsize=(12, 8))
IT = [12, 30, 1, 8, 22] 
ECE = [28, 6, 16, 5, 10] 

bar1 = np.arange(len(IT))
bar2 = [x + barWidth for x in bar1]

plt.bar(bar1, IT, width=0.2, label='IT', edgecolor='grey')
plt.bar(bar1, ECE, width=0.2, label='ECE', edgecolor='grey', bottom=IT)

plt.xlabel('Branch', fontweight='bold', fontsize=15)
plt.ylabel('Students Passed', fontweight='bold', fontsize=15)
plt.xticks([r + barWidth for r in range(len(IT))], 
        ['2015', '2016', '2017', '2018', '2019'])

plt.legend()
plt.show()

# %%
x = ['A', 'B', 'C', 'D']
y1 = np.array([10, 20, 10, 30])
y2 = np.array([20, 25, 15, 25])
y3 = np.array([12, 15, 19, 6])
y4 = np.array([10, 29, 13, 19])

plt.bar(x, y1, label='y1')
plt.bar(x, y2, label='y2', bottom=y1)
plt.bar(x, y3, label='y3', bottom=y1+y2)

plt.legend()
plt.show()

# %%
df = pd.DataFrame([['A', 10, 20, 10, 26], ['B', 20, 25, 15, 21], ['C', 12, 15, 19, 6],
                   ['D', 10, 18, 11, 19]],
                  columns=['Team', 'Round 1', 'Round 2', 'Round 3', 'Round 4'])

df.plot(x='Team', kind='bar')
plt.show()

# %%
df = pd.DataFrame([['A', 10, 20, 10, 26], ['B', 20, 25, 15, 21], ['C', 12, 15, 19, 6],
                   ['D', 10, 18, 11, 19]],
                  columns=['Team', 'Round 1', 'Round 2', 'Round 3', 'Round 4'])

df.plot(x='Team', kind='bar', stacked=True)
plt.show()

# %%
df = pd.DataFrame([['A', 10, 20, 10, 26], ['B', 20, 25, 15, 21], ['C', 12, 15, 19, 6],
                   ['D', 10, 18, 11, 19]],
                  columns=['Team', 'Round 1', 'Round 2', 'Round 3', 'Round 4'])

df.plot(x='Team', kind='barh', stacked=True, title="Stacked bar chart")
plt.show()

# %%
x = ['A', 'B', 'C', 'D']
y1 = np.array([10, 20, 10, 30])
y2 = np.array([20, 25, 15, 25])

plt.bar(x, y1, label='y1')
plt.bar(x, -y2, label='y2')

plt.legend()
plt.show()

# %%
x = ['A', 'B', 'C', 'D']
y1 = np.array([10, 20, 10, 30])
y2 = np.array([20, 25, 15, 25])

plt.barh(x, y1, label='y1')
plt.barh(x, -y2, label='y2')

plt.legend()
plt.show()

# %%
bars = plt.bar(["A", "B", "C", "D"], [10, 20, 30, 40])

plt.bar_label(bars, label_type='edge', color='blue')
plt.show()

# %%
x = [0, 1, 2, 3]
y = [10, 20, 30, 40]

plt.figure(figsize=(12,8))
plt.barh(x, y)
for i, j in enumerate(y):
    plt.text(j + 1, i, str(j), color='blue', fontweight='bold')

plt.show()

# %%
x = [0, 1, 2, 3]
y = [10, 20, 30, 40]

plt.figure(figsize=(12,8))
plt.bar(x, y)
for i, (xi, yi) in enumerate(zip(x, y)):
    plt.annotate(str(yi), xy=(xi, yi), xytext=(0, 10), textcoords='offset points', ha='center')

plt.show()

# %%
df
# Out:
#   Team  Round 1  Round 2  Round 3  Round 4
# 0    A       10       20       10       26
# 1    B       20       25       15       21
# 2    C       12       15       19        6
# 3    D       10       18       11       19

# %%
df = pd.read_csv('../../datasets/nba.csv')
df.dropna(inplace=True)

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
#
#       College     Salary
# 0       Texas  7730337.0
# 1   Marquette  6796117.0
# 6         LSU  1170960.0
# 7     Gonzaga  2165160.0
# 8  Louisville  1824360.0

# %%
plt.figure(figsize=(12, 8))

plt.bar(df['Team'][:50], df['Age'][:50], color='green', alpha=0.5, width=0.3)
for i, (xi, yi) in enumerate(zip(df['Team'][:50], df['Age'][:50])):
    plt.annotate(str(yi), xy=(xi, yi), xytext=(0, 10), textcoords='offset points', ha='center')

plt.xlabel('Team', fontsize=12)
plt.ylabel('Age', fontsize=12)
plt.title('Team Ages', fontsize=12)

plt.show()

# %%
data = np.random.randn(1000)
plt.hist(data, bins=30, color='orange', edgecolor='black')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %%
data = np.random.randn(1000)
sns.histplot(data, bins=30, color='green', kde=True, edgecolor='black')

plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %%
data1 = np.random.rand(1000)
data2 = np.random.rand(1000)

fig, axes = plt.subplots(figsize=(12, 6), nrows=2, ncols=2)

axes[0][0].hist(data1, bins=30, color='pink', edgecolor='black')
axes[0][0].set_title('Histogram1')

axes[1][0].hist(data2, bins=30, color='green', edgecolor='red')
axes[1][0].set_title('Histogram2')

plt.show()

# %%
data1 = np.random.rand(1000)
data2 = np.random.rand(1000)

plt.hist([data1, data2], bins=30, stacked=True, color=['pink', 'green'], edgecolor='black')

plt.show()

# %%
series1 = np.random.randn(500, 1)
series2 = np.random.randn(400, 1)

plt.hist(series1, bins='fd')
plt.hist(series2, bins='fd')

plt.show()

# %%
df = pd.read_csv('../../datasets/nba.csv')
df.dropna(inplace=True)
plt.hist(df['Age'])
plt.show()

# %%
df = pd.read_csv('../../datasets/nba.csv')
df.dropna(inplace=True)
plt.hist(df['Salary'])
plt.show()

# %%
x = np.array([12, 45, 7, 32, 89, 54, 23, 67, 14, 91])
y = np.array([99, 31, 72, 56, 19, 88, 43, 61, 35, 77])

plt.scatter(x, y, s=100, c='green', marker='*', edgecolors='red', alpha=0.6, label="xy")
plt.scatter(y, x, label="yx")
plt.title('Scatter diagram')
plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.legend(loc='lower right', ncol=2)
plt.show()

# %%
x = np.array([12, 45, 7, 32, 89, 54, 23, 67, 14, 91])
y = np.array([99, 31, 72, 56, 19, 88, 43, 61, 35, 77])

plt.scatter(x, y)
plt.plot(x, y)
plt.show()

# %%
df = pd.read_csv('../../datasets/nba.csv')
df.dropna(inplace=True)
plt.scatter(df['Age'],df['Salary'])
plt.show()

# %%
cars = ['AUDI', 'BMW', 'FORD',
        'TESLA', 'JAGUAR', 'MERCEDES']

data = [23, 17, 35, 29, 12, 41]

plt.pie(data, labels=cars)
plt.show()
